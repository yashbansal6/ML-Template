# %%
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv("../input/cat-in-the-dat-ii/train.csv")

# %%
df.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# 0   0    0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1   1    1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2   2    0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3   3    NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4   4    0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#    ...      nom_9 ord_0        ord_1     ord_2 ord_3 ord_4  ord_5  day month  \
# 0  ...  02e7c8990   3.0  Contributor       Hot     c     U     Pw  6.0   3.0
# 1  ...  f37df64af   3.0  Grandmaster      Warm     e     X     pE  7.0   7.0
# 2  ...        NaN   3.0          NaN  Freezing     n     P     eN  5.0   9.0
# 3  ...  f9d456e57   1.0       Novice  Lava Hot     a     C    NaN  3.0   3.0
# 4  ...  c5361037c   3.0  Grandmaster      Cold     h     C     OZ  5.0  12.0
#
#   target
# 0      0
# 1      0
# ...

# %%
df.bin_4.value_counts()
# Out:
# N    312344
# Y    269609
# Name: bin_4, dtype: int64

# %%
lbl = preprocessing.LabelEncoder()
lbl.fit(df.bin_0.values)
# Out:
# LabelEncoder()

# %%
#df.bin_0.values.tolist() : to see if we have NaN values
df.bin_0.values
# Out:
# array([0., 1., 0., ..., 0., 1., 0.])

# %%
#error due to Nan
lbl.transform(df.bin_0.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-602ca2e9ad12> in <module>
#       1 #error due to Nan
# ----> 2 lbl.transform(df.bin_0.values)
#
# ~/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/preprocessing/_label.py in transform(self, y)
#     271             return np.array([])
#     272
# --> 273         _, y = _encode(y, uniques=self.classes_, encode=True)
#     274         return y
#     275
#
# ~/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     116     else:
#     117         return _encode_numpy(values, uniques, encode,
# --> 118                              check_unknown=check_unknown)
#     119
#     120
#
# ~/opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/preprocessing/_label.py in _encode_numpy(values, uniques, encode, check_unknown)
# ...

# %% [markdown]
# Correct way is to fillna

# %%
lbl.fit(df.bin_0.fillna(-1).values)
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %%
df.bin_0.fillna(-1).values
# Out:
# array([0., 1., 0., ..., 0., 1., 0.])

# %%
lbl.transform(df.bin_0.fillna(-1).values)
# Out:
# array([[0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0],
#        ...,
#        [0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0]])

# %%
lbl = preprocessing.LabelBinarizer()
lbl.fit(df.bin_0.fillna(-1).values)
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %%
lbl.transform(df.bin_0.fillna(-1).values)
# Out:
# array([[0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0],
#        ...,
#        [0, 1, 0],
#        [0, 0, 1],
#        [0, 1, 0]])

# %%
df.bin_0
# Out:
# 0         0.0
# 1         1.0
# 2         0.0
# 3         NaN
# 4         0.0
#          ...
# 599995    0.0
# 599996    1.0
# 599997    0.0
# 599998    1.0
# 599999    0.0
# Name: bin_0, Length: 600000, dtype: float64

# %%
lbl = preprocessing.OneHotEncoder()
#expects 2D array and we pass 1D as only 1 column is passed-> reshape
lbl.fit(df.bin_0.fillna(-1).values.reshape(-1,1))
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
lbl.transform(df.bin_0.fillna(-1).values.reshape(-1,1))
# Out:
# <600000x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 600000 stored elements in Compressed Sparse Row format>

# %%
lbl = preprocessing.OneHotEncoder()
#no need to reshape as 2 columns passed
lbl.fit(df[["bin_0","bin_1"]].fillna(-1))
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
lbl.transform(df[["bin_0","bin_1"]].fillna(-1))
# Out:
# <600000x6 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1200000 stored elements in Compressed Sparse Row format>
